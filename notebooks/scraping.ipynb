# %% [markdown]
# #**Submission Proyek Analisis Sentimen**
# ---
# **Nama: Aikylla Zahra Permana**
#
# **ID: CACC409D6X2595**
#
# **Modul: Belajar Fundamental Deep Learning**
#
# ---
# Nama Aplikasi: iPusnas
#
# Library: google-play-scraper
#
# Target Data: Review, Rating, User Name, Date
#
# ---
# Tahap ini merupakan proses Data Acquisition atau pengumpulan data mentah yang dilakukan secara otomatis dari platform Google Play Store menggunakan library `google-play-scraper`. Fokus pengumpulan data diarahkan pada ulasan pengguna aplikasi iPusnas guna mendapatkan dataset yang akan digunakan dalam analisis sentimen menggunakan metode Machine Learning dan Deep Learning.

# %% [markdown]
# ##**SCRAPING DATA**

# %%
pip install google-play-scraper pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google_play_scraper import Sort, reviews
import pandas as pd
import datetime

# %%
app_id = 'mam.reader.ipusnas'


result, continuation_token = reviews(
    app_id,
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=12000
)

df = pd.DataFrame(result)

# %%
df = df[['content', 'score', 'at']]

df.columns = ['Review', 'Rating', 'Tanggal']

print(df.head())

print("\nDistribusi Rating:")
print(df['Rating'].value_counts().sort_index())

file_name = "ipusnas_reviews.csv"
df.to_csv(file_name, index=False)

print(f"\nFile berhasil disimpan: {file_name}")
# Out:
#                                               Review  Rating  \
# 0  login akun gabisa, daftar juga gabisa. ini pem...       1
# 1  Bukunya banyak yang gak bisa dibaca, udah pinj...       1
# 2                             why Ipusnas gila lagi😔       1
# 3  Sudah hilang sabarku.. Masalahnya udah pinjam ...       1
# 4  sudah semestinya segitu nilaimu, kalo bisa set...       1
#
#               Tanggal
# 0 2026-04-17 17:52:17
# 1 2026-04-17 09:56:55
# 2 2026-04-17 09:44:49
# 3 2026-04-17 04:46:38
# 4 2026-04-16 20:50:02
#
# Distribusi Rating:
# Rating
# 1    5922
# 2    1619
# 3    1478
# 4     879
# 5    2102
# Name: count, dtype: int64
#
# File berhasil disimpan: ipusnas_reviews.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Review   12000 non-null  object
#  1   Rating   12000 non-null  int64
#  2   Tanggal  12000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 281.4+ KB
